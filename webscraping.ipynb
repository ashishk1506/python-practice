# %%
import requests

# %%
result = requests.get("http://www.example.com")

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')
# Out:
# [<title>Example Domain</title>]

# %%
soup.select('p')
# Out:
# [<p>This domain is for use in illustrative examples in documents. You may use this
#      domain in literature without prior coordination or asking for permission.</p>,
#  <p><a href="https://www.iana.org/domains/example">More information...</a></p>]

# %%
soup.select('p')[0].getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
result = requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
soup = bs4.BeautifulSoup(result.text, 'lxml')

# %%
soup.select('title')
# Out:
# [<title>Wikipedia, the free encyclopedia</title>]

# %%
soup.select('.noprint')[0]
# Out:
# <div class="noprint" id="mw-page-base"></div>

# %%
#images

# %%
soup.select('img')[0]['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/6/62/Lou_Spence_1950_%28AWM148927%29_cropped.JPG/125px-Lou_Spence_1950_%28AWM148927%29_cropped.JPG'

# %%
<img 
 src="//upload.wikimedia.org/wikipedia/commons/thumb/6/62/Lou_Spence_1950_%28AWM148927%29_cropped.JPG/125px-Lou_Spence_1950_%28AWM148927%29_cropped.JPG"/>
# Out:
#   File "<ipython-input-25-9b3693828856>", line 1
#     <img
#     ^
# SyntaxError: invalid syntax

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/6/62/Lou_Spence_1950_%28AWM148927%29_cropped.JPG/125px-Lou_Spence_1950_%28AWM148927%29_cropped.JPG')

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C}\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x05\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x03\x04\x05\x07\x08\x02\x00\x01\t\xff\xc4\x00C\x10\x00\x02\x01\x03\x03\x02\x05\x01\x05\x05\x03\t\t\x00\x00\x00\x01\x02\x03\x04\x05\x11\x00\x12!\x061\x07\x13"AQa\x08\x142Bq\x15#\x81\x91\xa1R\xb1\xf0\x163br\xa2\xc1\xd1\xe1\xf1\x17$%C\x82\x83\x92\xa3\xb3\xff\xc4\x00\x18\x01\x00\x03\x01\x01\x00\x00\x
# ...

# %%
f = open('my_image','wb')

# %%
f.write(image_link.content)
# Out:
# 7317

# %%
f.close()
