# %%
from PIL import Image

# %%
cpu = Image.open("download.jpg")

# %%
rgb_im = cpu.convert('RGB')
rgb_im.save('download.jpg')

# %%
cpu.format
# Out:
# 'JPEG'

# %%
cpu.crop((10,50,300,168))
# Out:
# <PIL.Image.Image image mode=RGB size=290x118 at 0x2AAF89C74C0>

# %%
#copy and paste

# %%
c = cpu.crop((10,50,30,168))

# %%
cpu.paste(c,(0,0))

# %%
cpu
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x2AAF8E0E910>

# %%
cpu.resize((3000,100))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x100 at 0x2AAF8C42130>

# %%
cpu.rotate((90))
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x2AAF9E82F10>

# %%
cpu.putalpha(128)

# %%
cpu
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=300x168 at 0x2AAF8E0E910>

# %%
#excersize

# %%
from PIL import Image

# %%
matrix = Image.open(r'C:\Users\ASHISH KUMAR\Desktop\word_matrix.png')
mask = Image.open(r'C:\Users\ASHISH KUMAR\Desktop\mask.png')

# %%
matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
matrix.paste(mask,(0,0))

# %%
mask.putalpha(200)

# %%
n = mask.resize((1015,559))

# %%
matrix.paste(n,(0,0),n)

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x204CF0D6340>
